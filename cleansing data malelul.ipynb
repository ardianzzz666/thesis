# %%
import pandas as pd

data = pd.read_csv('datatesting.csv')

data.head()
# Out:
#   No_Index_Bumil_Dinas  Index_Simpus Tgl_Register               Nama  \
# 0                  NaN           NaN     10/07/20  AULIA MARIFATUN H
# 1     33090101  040718           NaN     03/07/18            SAFITRI
# 2     33090101  040718           NaN     03/07/18            SAFITRI
# 3     33090101  040718           NaN     03/07/18            SAFITRI
# 4     33090101  040718           NaN     03/07/18            SAFITRI
#
#    Kode_Pekerjaan_Istri Tgl_Lahir  Umur  Bulan  Hari  Agama_Istri  ...  \
# 0                    12  27/03/96    24      3    13            1  ...
# 1                     3  21/04/98    20      2    12            1  ...
# 2                     3  21/04/98    20      2    12            1  ...
# 3                     3  21/04/98    20      2    12            1  ...
# 4                     3  21/04/98    20      2    12            1  ...
#
#    ObatCacing TT4 TT5  HBSAG Rapid_Test  Protein_Urine  GDS  IMS      id  \
# ...

# %%
df = data.fillna(0)

df.head()
# Out:
#   No_Index_Bumil_Dinas  Index_Simpus Tgl_Register               Nama  \
# 0                    0           0.0     10/07/20  AULIA MARIFATUN H
# 1     33090101  040718           0.0     03/07/18            SAFITRI
# 2     33090101  040718           0.0     03/07/18            SAFITRI
# 3     33090101  040718           0.0     03/07/18            SAFITRI
# 4     33090101  040718           0.0     03/07/18            SAFITRI
#
#    Kode_Pekerjaan_Istri Tgl_Lahir  Umur  Bulan  Hari  Agama_Istri  ...  \
# 0                    12  27/03/96    24      3    13            1  ...
# 1                     3  21/04/98    20      2    12            1  ...
# 2                     3  21/04/98    20      2    12            1  ...
# 3                     3  21/04/98    20      2    12            1  ...
# 4                     3  21/04/98    20      2    12            1  ...
#
#    ObatCacing TT4 TT5  HBSAG Rapid_Test  Protein_Urine  GDS  IMS      id  \
# ...

# %%
df.to_csv('datatest2.csv', sep='\t', encoding='utf-8')
