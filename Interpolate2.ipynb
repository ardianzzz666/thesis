# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('data/jakarta/weather_maret_january.csv')
df = weather
weather.head()
# Out:
#          date    rh   avt   mxt   mnt
# 0  2020-03-18  86.0  27.6  29.0  25.8
# 1  2020-03-19  83.0  28.1  31.4  25.8
# 2  2020-03-20  82.0  27.4  31.2  25.2
# 3  2020-03-21  81.0  28.1  32.4   NaN
# 4  2020-03-22  84.0  27.2  31.2  25.0

# %%
df.date = pd.to_datetime(df.date)
df.set_index('date', inplace=True)

df.head()
# Out:
#               rh   avt   mxt   mnt
# date
# 2020-03-18  86.0  27.6  29.0  25.8
# 2020-03-19  83.0  28.1  31.4  25.8
# 2020-03-20  82.0  27.4  31.2  25.2
# 2020-03-21  81.0  28.1  32.4   NaN
# 2020-03-22  84.0  27.2  31.2  25.0

# %%
new_df = df.interpolate(method='spline', order=2)
new_df.plot()
plt.show()

# %%
new_df.to_csv('new_weather.csv')
